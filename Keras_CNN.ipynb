# %% [markdown]
# #**Deep Learning and Computer Vision**

# %% [markdown]
# Convolution Neural Networks are mainly use for large size input data such as Image data.
#
# Convolution Neural Networks (CNNs) use parameter sharing.
# Small pattern detectors called filters are used to convolve over the entire image.
# These filters are learned through NN training in the same way as in fully connected networks.
# Just like a hidden layer in a fully connected layer, convolution layers are used in CNNs.
# To handle large size of image data, pooling layers are introduced.
# Normalization layers were used in early CNN architectures, but due to their minimal impact, they are not much used in the present CNNs.

# %% [markdown]
# ## This tutorial is divided into two sections
# ### Section 1: Creating, training and testing a custom CNN classifier.
# ### Section 2: Generating feature maps of an input from the already trained CNN.
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# **Section 1: Lets create and train the CNN classifier using tensorflow and keras libraries.**

# %% [markdown]
# **Divide the dataset into train,validation,test sets**

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/d1/4b/7b282b0f9319189d71e803220748929b37d019b67b1782d14c59cb1bd940/split_folders-0.4.2-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import splitfolders
input_folder='/content/drive/My Drive/Canvas/Day 1/rps-cv-images/rps-cv-images'
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio(input_folder, output="output", seed=2000, ratio=(.8, .1, .1)) #default values
# Out:
# Copying files: 2182 files [08:12,  4.43 files/s]

# %% [markdown]
# **Import necessary packages**

# %%
import os
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense,Input
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, Conv2D
from keras import optimizers
from keras import applications
from keras.models import Model
from keras import models

# %% [markdown]
# **Defining size of image**

# %%
img_width, img_height = 200,300

# %% [markdown]
# **Defining paths to the dataset**

# %%
train_data_dir = 'output/train'
validation_data_dir = 'output/val'
test_data_dir = 'output/test'

# %% [markdown]
# **Define the data generators taking input from folder specified above**

# %%
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
batch_size = 32

# %%
train_generator = train_datagen.flow_from_directory(
       train_data_dir,
       target_size=(img_width, img_height),
       color_mode='rgb',
       shuffle='True',
       batch_size=32,
       class_mode='categorical',seed=25)

validation_generator = validation_datagen.flow_from_directory(
       validation_data_dir,
       target_size=(img_width, img_height),color_mode='rgb',
       batch_size=32,
       class_mode='categorical',seed=25)

test_generator = test_datagen.flow_from_directory(
       test_data_dir,
       target_size=(img_width, img_height),color_mode='rgb',
       batch_size=1,
       class_mode='categorical',shuffle=False,seed=25)
# Out:
# Found 1745 images belonging to 3 classes.
# Found 217 images belonging to 3 classes.
# Found 220 images belonging to 3 classes.

# %% [markdown]
# ### Model Building
# We are going to use 2 convolution layers with 3x3 filer and relu as an activation function
# Then max pooling layer with 2x2 filter is used
# After that we are going to use Flatten layer
# Then Dense layer is used with relu function
# In the output layer softmax function is used with 4 neurons as we have four class dataset.
# model.summary() is used to check the overall architecture of the model with number of learnable parameters in each

# %%
model = Sequential()
model.add(Convolution2D(8, (3, 3), input_shape=(img_width, img_height,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(8, (5, 5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# 2-d
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
# model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 298, 8)       224
# _________________________________________________________________
# activation (Activation)      (None, 198, 298, 8)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 149, 8)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 95, 145, 8)        1608
# _________________________________________________________________
# activation_1 (Activation)    (None, 95, 145, 8)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 72, 8)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 27072)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6930688
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# _________________________________________________________________
# activation_3 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 6,933,291
# Trainable params: 6,933,291
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Comiling model with specifying loss function ,optimizer, metrics

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %% [markdown]
# ### Start the training

# %%
from keras.callbacks import ModelCheckpoint
filepath='best_weights.hdf5'
checkpointer=ModelCheckpoint(filepath,monitor='val_accuracy',mode='max',save_best_only=True,verbose=1)
epochs = 50

history=model.fit_generator(
        train_generator,
        steps_per_epoch=train_generator.samples // train_generator.batch_size,
        epochs=epochs,
        callbacks=[checkpointer],
        validation_data=validation_generator,
        validation_steps=validation_generator.samples//validation_generator.batch_size)
# Out:
# WARNING:tensorflow:From <ipython-input-13-870b9aa4785f>:12: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 54/54 [==============================] - ETA: 0s - loss: 0.9230 - accuracy: 0.5616
# Epoch 00001: val_accuracy improved from -inf to 0.61979, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 113ms/step - loss: 0.9230 - accuracy: 0.5616 - val_loss: 0.8421 - val_accuracy: 0.6198
# Epoch 2/50
# 54/54 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.7618
# Epoch 00002: val_accuracy improved from 0.61979 to 0.63021, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 109ms/step - loss: 0.6229 - accuracy: 0.7618 - val_loss: 0.8004 - val_accuracy: 0.6302
# Epoch 3/50
# 54/54 [==============================] - ETA: 0s - loss: 0.4955 - accuracy: 0.8114
# Epoch 00003: val_accuracy improved from 0.63021 to 0.88021, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 110ms/step - loss: 0.4955 - accuracy: 0.8114 - val_loss: 0.3130 - val_accuracy: 0.8802
# Epoch 4/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3539 - accuracy: 0.8657
# Epoch 00004: val_accuracy did not improve from 0.88021
# 54/54 [==============================] - 6s 109ms/step - loss: 0.3539 - accuracy: 0.8657 - val_loss: 0.3708 - val_accuracy: 0.8750
# Epoch 5/50
# 54/54 [==============================] - ETA: 0s - loss: 0.3445 - accuracy: 0.8809
# Epoch 00005: val_accuracy improved from 0.88021 to 0.89583, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 109ms/step - loss: 0.3445 - accuracy: 0.8809 - val_loss: 0.2992 - val_accuracy: 0.8958
# Epoch 6/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9229
# Epoch 00006: val_accuracy improved from 0.89583 to 0.94271, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 109ms/step - loss: 0.2364 - accuracy: 0.9229 - val_loss: 0.1736 - val_accuracy: 0.9427
# Epoch 7/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.9124
# Epoch 00007: val_accuracy improved from 0.94271 to 0.94792, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 109ms/step - loss: 0.2545 - accuracy: 0.9124 - val_loss: 0.1518 - val_accuracy: 0.9479
# Epoch 8/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9381
# Epoch 00008: val_accuracy improved from 0.94792 to 0.96354, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 109ms/step - loss: 0.1759 - accuracy: 0.9381 - val_loss: 0.1388 - val_accuracy: 0.9635
# Epoch 9/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9282
# Epoch 00009: val_accuracy improved from 0.96354 to 0.96875, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 110ms/step - loss: 0.2026 - accuracy: 0.9282 - val_loss: 0.1465 - val_accuracy: 0.9688
# Epoch 10/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9521
# Epoch 00010: val_accuracy did not improve from 0.96875
# 54/54 [==============================] - 6s 108ms/step - loss: 0.1475 - accuracy: 0.9521 - val_loss: 0.1908 - val_accuracy: 0.9219
# Epoch 11/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9603
# Epoch 00011: val_accuracy improved from 0.96875 to 0.97396, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 110ms/step - loss: 0.1171 - accuracy: 0.9603 - val_loss: 0.0780 - val_accuracy: 0.9740
# Epoch 12/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9749
# Epoch 00012: val_accuracy did not improve from 0.97396
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0926 - accuracy: 0.9749 - val_loss: 0.1521 - val_accuracy: 0.9323
# Epoch 13/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9772
# Epoch 00013: val_accuracy did not improve from 0.97396
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0911 - accuracy: 0.9772 - val_loss: 0.0949 - val_accuracy: 0.9688
# Epoch 14/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9486
# Epoch 00014: val_accuracy improved from 0.97396 to 0.97917, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 109ms/step - loss: 0.1783 - accuracy: 0.9486 - val_loss: 0.0611 - val_accuracy: 0.9792
# Epoch 15/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9492
# Epoch 00015: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 108ms/step - loss: 0.1393 - accuracy: 0.9492 - val_loss: 0.0790 - val_accuracy: 0.9740
# Epoch 16/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9848
# Epoch 00016: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0605 - accuracy: 0.9848 - val_loss: 0.1270 - val_accuracy: 0.9375
# Epoch 17/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9854
# Epoch 00017: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0557 - accuracy: 0.9854 - val_loss: 0.0662 - val_accuracy: 0.9792
# Epoch 18/50
# 54/54 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9568
# Epoch 00018: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 107ms/step - loss: 0.1739 - accuracy: 0.9568 - val_loss: 0.0908 - val_accuracy: 0.9635
# Epoch 19/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9848
# Epoch 00019: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0633 - accuracy: 0.9848 - val_loss: 0.0702 - val_accuracy: 0.9688
# Epoch 20/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9872
# Epoch 00020: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0478 - accuracy: 0.9872 - val_loss: 0.0482 - val_accuracy: 0.9792
# Epoch 21/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9848
# Epoch 00021: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0541 - accuracy: 0.9848 - val_loss: 0.0647 - val_accuracy: 0.9688
# Epoch 22/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9872
# Epoch 00022: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0391 - accuracy: 0.9872 - val_loss: 0.1734 - val_accuracy: 0.9375
# Epoch 23/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9918
# Epoch 00023: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0308 - accuracy: 0.9918 - val_loss: 0.0430 - val_accuracy: 0.9792
# Epoch 24/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9930
# Epoch 00024: val_accuracy did not improve from 0.97917
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0255 - accuracy: 0.9930 - val_loss: 0.0516 - val_accuracy: 0.9792
# Epoch 25/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9942
# Epoch 00025: val_accuracy improved from 0.97917 to 0.98438, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0217 - accuracy: 0.9942 - val_loss: 0.0353 - val_accuracy: 0.9844
# Epoch 26/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9901
# Epoch 00026: val_accuracy did not improve from 0.98438
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.0655 - val_accuracy: 0.9688
# Epoch 27/50
# 54/54 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9632
# Epoch 00027: val_accuracy did not improve from 0.98438
# 54/54 [==============================] - 6s 107ms/step - loss: 0.2371 - accuracy: 0.9632 - val_loss: 0.1319 - val_accuracy: 0.9583
# Epoch 28/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9784
# Epoch 00028: val_accuracy did not improve from 0.98438
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0718 - accuracy: 0.9784 - val_loss: 0.0647 - val_accuracy: 0.9740
# Epoch 29/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9918
# Epoch 00029: val_accuracy improved from 0.98438 to 0.99479, saving model to best_weights.hdf5
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0382 - accuracy: 0.9918 - val_loss: 0.0342 - val_accuracy: 0.9948
# Epoch 30/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9918
# Epoch 00030: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0272 - accuracy: 0.9918 - val_loss: 0.0417 - val_accuracy: 0.9688
# Epoch 31/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9936
# Epoch 00031: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0249 - accuracy: 0.9936 - val_loss: 0.0226 - val_accuracy: 0.9948
# Epoch 32/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9982
# Epoch 00032: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0156 - accuracy: 0.9982 - val_loss: 0.0204 - val_accuracy: 0.9948
# Epoch 33/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9895
# Epoch 00033: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0284 - accuracy: 0.9895 - val_loss: 0.0450 - val_accuracy: 0.9844
# Epoch 34/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9942
# Epoch 00034: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.0336 - val_accuracy: 0.9896
# Epoch 35/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9977
# Epoch 00035: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.0269 - val_accuracy: 0.9792
# Epoch 36/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9988
# Epoch 00036: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0075 - accuracy: 0.9988 - val_loss: 0.0281 - val_accuracy: 0.9844
# Epoch 37/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9994
# Epoch 00037: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 0.0268 - val_accuracy: 0.9844
# Epoch 38/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9988
# Epoch 00038: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0294 - val_accuracy: 0.9792
# Epoch 39/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9740
# Epoch 40/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9896
# Epoch 41/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 108ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9948
# Epoch 42/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9948
# Epoch 43/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9948
# Epoch 44/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9844
# Epoch 45/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 105ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9896
# Epoch 46/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9948
# Epoch 47/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9896
# Epoch 48/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9896
# Epoch 49/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 106ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9896
# Epoch 50/50
# 54/54 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.99479
# 54/54 [==============================] - 6s 107ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9896

# %% [markdown]
# ### Optional: We can load best weights

# %%
model.load_weights('best_weights.hdf5')

# %% [markdown]
# ### Model evaluation on validation dataset

# %%
model.evaluate_generator(test_generator, test_generator.samples)
# Out:
# [0.05512169748544693, 0.9772727489471436]

# %% [markdown]
# ### Optional: We can save the model weights

# %%
model.save_weights('cnn_classification.hdf5')
model.load_weights('cnn_classification.hdf5')

# %% [markdown]
# ### Optional: We can also save the whole model.

# %%
model.save('cnn_classification.h5')
model = models.load_model('cnn_classification.h5')

# %% [markdown]
# ### Plotting the metrics for comparison

# %%
import matplotlib.pyplot as plt
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(train_acc)) 
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.show()

plt.plot(epochs, train_loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# **Testing the model and exporting the results to a csv file**

# %%
test_generator.reset()
filenames=test_generator.filenames
nb_samples=len(filenames)
pred=model.predict_generator(test_generator,steps=nb_samples)
# Out:
# WARNING:tensorflow:From <ipython-input-21-0a454e27e5ee>:4: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
predicted_class_indices=np.argmax(pred,axis=1)

# %%
labels=(train_generator.class_indices)
labels=dict((v,k) for k,v in labels.items())
predictions=[labels[k] for k in predicted_class_indices]

# %%
filenames=test_generator.filenames
results=pd.DataFrame({"Filename":filenames,"Predictions":predictions})
results.to_csv("results.csv",index=False)

# %% [markdown]
# ## Section-II : Generating featutre maps
#
# In this section we are going to use 'KERACT' library provided by PyPi, for genetaing the intermediate activations

# %%
# !pip install keract
# Out:
# Collecting keract
#   Downloading https://files.pythonhosted.org/packages/38/81/9024583b107451dbd8358073a0e9235cfbd07ccce1c8ed33c7a651a9c0cc/keract-4.3.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from keract) (1.18.5)
# Installing collected packages: keract
# Successfully installed keract-4.3.0

# %%
from keract import get_activations
import numpy as np

# %%
from skimage.color import rgb2gray
input_image=plt.imread('/content/drive/My Drive/Canvas/Day 1/test_rps')

# %%
plt.imshow(input_image)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 198, 298, 8)       224
# _________________________________________________________________
# activation_1 (Activation)    (None, 198, 298, 8)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 99, 149, 8)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 95, 145, 8)        1608
# _________________________________________________________________
# activation_2 (Activation)    (None, 95, 145, 8)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 47, 72, 8)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 27072)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6930688
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# _________________________________________________________________
# activation_4 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 6,933,291
# Trainable params: 6,933,291
# Non-trainable params: 0
# _________________________________________________________________

# %%
from PIL import Image
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import keract
image = img_to_array(input_image)
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
activations = keract.get_activations(model,image)
# first = activations.get('block1_conv1/Relu:0')
keract.display_activations(activations)
# Out:
# conv2d_1_1 (1, 198, 298, 8)
# activation_1_1 (1, 198, 298, 8)
# max_pooling2d_1_1 (1, 99, 149, 8)
# conv2d_2_1 (1, 95, 145, 8)
# activation_2_1 (1, 95, 145, 8)
# max_pooling2d_2_1 (1, 47, 72, 8)
# flatten_1_1 (1, 27072)
# dense_1_1 (1, 256)
# activation_3_1 (1, 256)
# dense_2_1 (1, 3)
# activation_4_1 (1, 3)
