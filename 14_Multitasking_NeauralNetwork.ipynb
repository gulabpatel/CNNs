# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/ANN_CNN_TransferLearning/blob/master/14_Multitasking_NeauralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras import Model, layers, optimizers, callbacks, losses, metrics
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
sns.set_theme()

import matplotlib.pyplot as plt

# %% [markdown]
# # News Popularity Data

# %%
data = pd.read_csv("https://raw.githubusercontent.com/gulabpatel/ANN_CNN_TransferLearning/master/dataset/OnlineNewsPopularity.csv")
data.columns = [col.strip() for col in data.columns]
data = data[data['shares']<100000]
data.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# 1                  0.791946        3.0             1.0       1.0  ...
# 2                  0.663866        3.0             1.0       1.0  ...
# 3                  0.665635        9.0             0.0       1.0  ...
# 4                  0.540890       19.0            19.0      20.0  ...
#
#    min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 0               0.100000                    0.7              -0.350000
# 1               0.033333                    0.7              -0.118750
# 2               0.100000                    1.0              -0.466667
# 3               0.136364                    0.8              -0.369697
# 4               0.033333                    1.0              -0.220192
#
#    min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 0                 -0.600              -0.200000            0.500000
# 1                 -0.125              -0.100000            0.000000
# 2                 -0.800              -0.133333            0.000000
# 3                 -0.600              -0.166667            0.000000
# 4                 -0.500              -0.050000            0.454545
#
#    title_sentiment_polarity  abs_title_subjectivity  \
# 0                 -0.187500                0.000000
# 1                  0.000000                0.500000
# 2                  0.000000                0.500000
# 3                  0.000000                0.500000
# 4                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares
# 0                      0.187500     593
# 1                      0.000000     711
# 2                      0.000000    1500
# 3                      0.000000    1200
# 4                      0.136364     505
#
# [5 rows x 61 columns]

# %%
data['shares'].describe(percentiles=[0.1,0.5,0.95])
# Out:
# count    39586.000000
# mean      3100.751579
# std       5991.066519
# min          1.000000
# 10%        708.000000
# 50%       1400.000000
# 95%      10600.000000
# max      98700.000000
# Name: shares, dtype: float64

# %%
data['shares'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
high_share_thresh = 10000
data["high_shares_y_n"] = data["shares"].apply(lambda shares: 1 if shares>high_share_thresh else 0)

# %%
data.dtypes.value_counts()
# Out:
# float64    59
# int64       2
# object      1
# dtype: int64

# %%
data.drop("url", axis=1, inplace=True)
data.shape
# Out:
# (39586, 61)

# %%
data.head()
# Out:
#    timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0      731.0            12.0             219.0         0.663594
# 1      731.0             9.0             255.0         0.604743
# 2      731.0             9.0             211.0         0.575130
# 3      731.0             9.0             531.0         0.503788
# 4      731.0            13.0            1072.0         0.415646
#
#    n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0               1.0                  0.815385        4.0             2.0
# 1               1.0                  0.791946        3.0             1.0
# 2               1.0                  0.663866        3.0             1.0
# 3               1.0                  0.665635        9.0             0.0
# 4               1.0                  0.540890       19.0            19.0
#
#    num_imgs  num_videos  ...  max_positive_polarity  avg_negative_polarity  \
# 0       1.0         0.0  ...                    0.7              -0.350000
# 1       1.0         0.0  ...                    0.7              -0.118750
# 2       1.0         0.0  ...                    1.0              -0.466667
# 3       1.0         0.0  ...                    0.8              -0.369697
# 4      20.0         0.0  ...                    1.0              -0.220192
#
#    min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 0                 -0.600              -0.200000            0.500000
# 1                 -0.125              -0.100000            0.000000
# 2                 -0.800              -0.133333            0.000000
# 3                 -0.600              -0.166667            0.000000
# 4                 -0.500              -0.050000            0.454545
#
#    title_sentiment_polarity  abs_title_subjectivity  \
# 0                 -0.187500                0.000000
# 1                  0.000000                0.500000
# 2                  0.000000                0.500000
# 3                  0.000000                0.500000
# 4                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares  high_shares_y_n
# 0                      0.187500     593                0
# 1                      0.000000     711                0
# 2                      0.000000    1500                0
# 3                      0.000000    1200                0
# 4                      0.136364     505                0
#
# [5 rows x 61 columns]

# %%
data.describe()
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39586.000000    39586.000000      39586.000000     39586.000000
# mean     354.523417       10.397994        546.517254         0.548278
# std      214.209866        2.113984        470.721844         3.523278
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470864
# 50%      339.000000       10.000000        409.500000         0.539216
# 75%      542.000000       12.000000        716.000000         0.608584
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39586.000000              39586.000000  39586.000000
# mean           0.996615                  0.689271     10.878619
# std            5.235048                  3.267194     11.327396
# min            0.000000                  0.000000      0.000000
# 25%            1.000000                  0.625767      4.000000
# 50%            1.000000                  0.690476      8.000000
# 75%            1.000000                  0.754627     14.000000
# max         1042.000000                650.000000    304.000000
#
#        num_self_hrefs      num_imgs    num_videos  ...  max_positive_polarity  \
# count    39586.000000  39586.000000  39586.000000  ...           39586.000000
# mean         3.294271      4.541757      1.248446  ...               0.756760
# std          3.855810      8.308267      4.108235  ...               0.247678
# min          0.000000      0.000000      0.000000  ...               0.000000
# 25%          1.000000      1.000000      0.000000  ...               0.600000
# 50%          3.000000      1.000000      0.000000  ...               0.800000
# 75%          4.000000      4.000000      1.000000  ...               1.000000
# max        116.000000    128.000000     91.000000  ...               1.000000
#
#        avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# count           39586.000000           39586.000000           39586.000000
# mean               -0.259474              -0.521874              -0.107452
# std                 0.127641               0.290188               0.095269
# min                -1.000000              -1.000000              -1.000000
# 25%                -0.328282              -0.700000              -0.125000
# 50%                -0.253333              -0.500000              -0.100000
# 75%                -0.186905              -0.300000              -0.050000
# max                 0.000000               0.000000               0.000000
#
#        title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# count        39586.000000              39586.000000            39586.000000
# mean             0.282267                  0.071432                0.341809
# std              0.324161                  0.265346                0.188803
# min              0.000000                 -1.000000                0.000000
# 25%              0.000000                  0.000000                0.166667
# 50%              0.150000                  0.000000                0.500000
# 75%              0.500000                  0.148504                0.500000
# max              1.000000                  1.000000                0.500000
#
#        abs_title_sentiment_polarity        shares  high_shares_y_n
# count                  39586.000000  39586.000000     39586.000000
# mean                       0.155989   3100.751579         0.053731
# std                        0.226225   5991.066519         0.225489
# min                        0.000000      1.000000         0.000000
# 25%                        0.000000    945.000000         0.000000
# 50%                        0.000000   1400.000000         0.000000
# 75%                        0.250000   2800.000000         0.000000
# max                        1.000000  98700.000000         1.000000
#
# [8 rows x 61 columns]

# %%
unique_counts= pd.DataFrame()
counts = []
for col in data.columns:
    counts.append(data[col].nunique())

unique_counts['feature'] = data.columns
unique_counts['unique_count'] = counts
unique_counts = unique_counts.sort_values(by='unique_count')

# %% [markdown]
# # Preprocess Data

# %%
targets = ['shares', 'high_shares_y_n']
features = [col for col in data.columns if col not in targets]

# %%
X, y = data.drop(targets, axis=1), data[targets]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

y_train = y_train.astype('float')
y_test = y_test.astype('float')

# %%
y_test['shares'].describe()
# Out:
# count     3959.000000
# mean      3067.948472
# std       5827.827336
# min          8.000000
# 25%        933.500000
# 50%       1400.000000
# 75%       2700.000000
# max      81700.000000
# Name: shares, dtype: float64

# %%
y_train['shares'].describe()
# Out:
# count    35627.000000
# mean      3104.396778
# std       6009.001248
# min          1.000000
# 25%        947.000000
# 50%       1400.000000
# 75%       2800.000000
# max      98700.000000
# Name: shares, dtype: float64

# %%
unique_counts[unique_counts['unique_count']==2]
# Out:
#                           feature  unique_count
# 30              weekday_is_monday             2
# 37                     is_weekend             2
# 36              weekday_is_sunday             2
# 35            weekday_is_saturday             2
# 34              weekday_is_friday             2
# 33            weekday_is_thursday             2
# 32           weekday_is_wednesday             2
# 31             weekday_is_tuesday             2
# 17          data_channel_is_world             2
# 16           data_channel_is_tech             2
# 15         data_channel_is_socmed             2
# 14            data_channel_is_bus             2
# 13  data_channel_is_entertainment             2
# 60                high_shares_y_n             2
# 12      data_channel_is_lifestyle             2

# %%
scale_feats, do_not_scale = [], []

for feature in features:
    if X_train[feature].nunique()>2:
        scale_feats.append(feature)
    else:
        do_not_scale.append(feature)

# %%
scaler = StandardScaler()

X_train.loc[:, scale_feats] = scaler.fit_transform(X_train[scale_feats])
X_test.loc[:, scale_feats] = scaler.transform(X_test[scale_feats])

output_scaler = StandardScaler()
y_train.loc[:, 'shares'] = [val[0] for val in output_scaler.fit_transform(y_train['shares'].values.reshape(-1,1))]
y_test.loc[:, 'shares'] = [val[0] for val in output_scaler.transform(y_test['shares'].values.reshape(-1,1))]

# %% [markdown]
# # Define Model Architecture

# %%
num_features = len(features)

shared_dense_units_list = [64, 32]
regression_dense_units_list = [64, 16]
classification_dense_units_list = [32, 16]

# %%
def multi_task_model(num_features, shared_dense_units_list, regression_dense_units_list, classification_dense_units_list, batch_norm):
    
    # Input
    input_ = layers.Input(shape=(num_features,), name='Input')
    shared_x = layers.BatchNormalization(name=f'bn_inp')(input_)

    # Shared Layers
    for i, dense_units in enumerate(shared_dense_units_list):
        shared_x = layers.Dense(units = dense_units, name=f'shared_dense_{i+1}')(shared_x)
        shared_x = layers.ReLU(name=f'shared_relu_{i+1}')(shared_x)

        if batch_norm:
            shared_x = layers.BatchNormalization(name=f'shared_bn_{i+1}')(shared_x)

        shared_x = layers.Dropout(0.2, name=f'shared_dropout_{i+1}')(shared_x)


    # Regression Head
    if len(regression_dense_units_list)>0:
        regr_x = layers.Dense(units = regression_dense_units_list[0], name='regr_dense_1')(shared_x)
        regr_x = layers.ReLU(name=f'regr_relu_1')(regr_x)

    for i, dense_units in enumerate(regression_dense_units_list[1:]):
        regr_x = layers.Dense(units = dense_units, name=f'regr_dense_{i+2}')(regr_x)
        regr_x = layers.ReLU(name=f'regr_relu_{i+2}')(regr_x)

        if batch_norm:
            regr_x = layers.BatchNormalization(name=f'regr_bn_{i+1}')(regr_x)

        regr_x = layers.Dropout(0.2, name=f'regr_dropout_{i+1}')(regr_x)

    if len(regression_dense_units_list)>0:
        regr_output = layers.Dense(1, name='regr_out')(regr_x)
    else:
        regr_output = layers.Dense(1, name='regr_out')(shared_x)


    # Classification Head
    if len(classification_dense_units_list)>0:
        clsf_x = layers.Dense(units = classification_dense_units_list[0], name='clsf_dense_1')(shared_x)
        clsf_x = layers.ReLU(name=f'clsf_relu_1')(clsf_x)

    for i, dense_units in enumerate(classification_dense_units_list[1:]):
        clsf_x = layers.Dense(units = dense_units, name=f'clsf_dense_{i+2}')(clsf_x)
        clsf_x = layers.ReLU(name=f'clsf_relu_{i+2}')(clsf_x)

        if batch_norm:
            clsf_x = layers.BatchNormalization(name=f'clsf_bn_{i+1}')(clsf_x)

        clsf_x = layers.Dropout(0.2, name=f'clsf_dropout_{i+1}')(clsf_x)

    if len(classification_dense_units_list)>0:
        clsf_output = layers.Dense(1, name='p_clsf', activation='sigmoid')(clsf_x)
    else:
        clsf_output = layers.Dense(1, name='p_clsf', activation='sigmoid')(shared_x)


    model = Model(input_, [regr_output, clsf_output], name='model')
    
    return model



def plot_metrics(model_history, metrics):
    
    n_cols = 2
    n_rows = int(np.ceil(len(metrics)/n_cols))
    
    fig, ax = plt.subplots(n_rows, n_cols, sharex=False, sharey=False, figsize=(12,5*n_rows))
    ax = np.array(ax)
    ax = ax.flatten()

    for i, metric in enumerate(metrics):
        ax[i].plot(model_history.history[metric], label='Training')
        ax[i].plot(model_history.history['val_'+metric], label='Validation')
        ax[i].set_title(metric)
        ax[i].legend()
        ax[i].set(xlabel='Epoch')

    fig.tight_layout()
    plt.show()

    return fig

# %%
model = multi_task_model(num_features=num_features,
                        shared_dense_units_list=shared_dense_units_list,
                        regression_dense_units_list=regression_dense_units_list,
                        classification_dense_units_list=classification_dense_units_list,
                        batch_norm=False)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 59)]         0           []
#
#  bn_inp (BatchNormalization)    (None, 59)           236         ['Input[0][0]']
#
#  shared_dense_1 (Dense)         (None, 64)           3840        ['bn_inp[0][0]']
#
#  shared_relu_1 (ReLU)           (None, 64)           0           ['shared_dense_1[0][0]']
#
#  shared_dropout_1 (Dropout)     (None, 64)           0           ['shared_relu_1[0][0]']
#
#  shared_dense_2 (Dense)         (None, 32)           2080        ['shared_dropout_1[0][0]']
#
#  shared_relu_2 (ReLU)           (None, 32)           0           ['shared_dense_2[0][0]']
#
#  shared_dropout_2 (Dropout)     (None, 32)           0           ['shared_relu_2[0][0]']
#
#  regr_dense_1 (Dense)           (None, 64)           2112        ['shared_dropout_2[0][0]']
#
#  clsf_dense_1 (Dense)           (None, 32)           1056        ['shared_dropout_2[0][0]']
#
#  regr_relu_1 (ReLU)             (None, 64)           0           ['regr_dense_1[0][0]']
#
#  clsf_relu_1 (ReLU)             (None, 32)           0           ['clsf_dense_1[0][0]']
#
#  regr_dense_2 (Dense)           (None, 16)           1040        ['regr_relu_1[0][0]']
#
#  clsf_dense_2 (Dense)           (None, 16)           528         ['clsf_relu_1[0][0]']
#
#  regr_relu_2 (ReLU)             (None, 16)           0           ['regr_dense_2[0][0]']
#
#  clsf_relu_2 (ReLU)             (None, 16)           0           ['clsf_dense_2[0][0]']
#
#  regr_dropout_1 (Dropout)       (None, 16)           0           ['regr_relu_2[0][0]']
#
#  clsf_dropout_1 (Dropout)       (None, 16)           0           ['clsf_relu_2[0][0]']
#
#  regr_out (Dense)               (None, 1)            17          ['regr_dropout_1[0][0]']
#
#  p_clsf (Dense)                 (None, 1)            17          ['clsf_dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 10,926
# Trainable params: 10,808
# Non-trainable params: 118
# __________________________________________________________________________________________________

# %% [markdown]
# # Train Model

# %%
import tensorflow.keras.backend as K
def scaled_mse(y_true, y_pred):
    #difference between true label and predicted label
    error = y_true-y_pred    
    #square of the error
    sqr_error = K.square(error)
    #mean of the square of the error
    mean_sqr_error = K.mean(sqr_error)

    return mean_sqr_error/3.

    

def output_form(data):
    regr = data['shares']
    regr = np.array(regr)
    clsf = data['high_shares_y_n']
    clsf = np.array(clsf)
    return (regr, clsf)

train_y = output_form(y_train)
test_y = output_form(y_test)

# %%
EPOCHS = 500

# %%
learning_rate = 1e-04

# Compile Model
opt = optimizers.Adam(learning_rate)
model.compile(optimizer=opt,
                loss={'p_clsf' : tf.keras.losses.BinaryCrossentropy(),
                     'regr_out' : tf.keras.losses.MeanSquaredError()},
                metrics={'p_clsf':[tf.keras.metrics.AUC(name='auc')],
                        'regr_out': [tf.keras.metrics.RootMeanSquaredError(name='rmse'), tf.keras.metrics.MeanAbsolutePercentageError(name='mape')]})

# %%
early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True, min_delta=0.001)

# Fit
history = model.fit(x=X_train.values,
                    y=train_y,
                    validation_data = (X_test.values, test_y),
                    epochs=EPOCHS,
                    callbacks=[early_stop],
                    batch_size=64)
# Out:
# Epoch 1/500
# 557/557 [==============================] - 5s 5ms/step - loss: 1.4609 - regr_out_loss: 1.0286 - p_clsf_loss: 0.4323 - regr_out_rmse: 1.0142 - regr_out_mape: 270.2967 - p_clsf_auc: 0.4909 - val_loss: 1.1636 - val_regr_out_loss: 0.9293 - val_p_clsf_loss: 0.2343 - val_regr_out_rmse: 0.9640 - val_regr_out_mape: 156.8165 - val_p_clsf_auc: 0.4893
# Epoch 2/500
# 557/557 [==============================] - 4s 7ms/step - loss: 1.2491 - regr_out_loss: 0.9966 - p_clsf_loss: 0.2525 - regr_out_rmse: 0.9983 - regr_out_mape: 187.4075 - p_clsf_auc: 0.4966 - val_loss: 1.1321 - val_regr_out_loss: 0.9236 - val_p_clsf_loss: 0.2084 - val_regr_out_rmse: 0.9610 - val_regr_out_mape: 161.6756 - val_p_clsf_auc: 0.5609
# Epoch 3/500
# 557/557 [==============================] - 6s 11ms/step - loss: 1.2227 - regr_out_loss: 0.9892 - p_clsf_loss: 0.2334 - regr_out_rmse: 0.9946 - regr_out_mape: 198.5152 - p_clsf_auc: 0.5533 - val_loss: 1.1170 - val_regr_out_loss: 0.9194 - val_p_clsf_loss: 0.1976 - val_regr_out_rmse: 0.9589 - val_regr_out_mape: 174.2374 - val_p_clsf_auc: 0.6313
# Epoch 4/500
# 557/557 [==============================] - 5s 8ms/step - loss: 1.2090 - regr_out_loss: 0.9849 - p_clsf_loss: 0.2241 - regr_out_rmse: 0.9924 - regr_out_mape: 193.6203 - p_clsf_auc: 0.5980 - val_loss: 1.1048 - val_regr_out_loss: 0.9129 - val_p_clsf_loss: 0.1919 - val_regr_out_rmse: 0.9555 - val_regr_out_mape: 189.6998 - val_p_clsf_auc: 0.6805
# Epoch 5/500
# 557/557 [==============================] - 4s 8ms/step - loss: 1.2010 - regr_out_loss: 0.9807 - p_clsf_loss: 0.2203 - regr_out_rmse: 0.9903 - regr_out_mape: 221.5509 - p_clsf_auc: 0.6122 - val_loss: 1.0977 - val_regr_out_loss: 0.9084 - val_p_clsf_loss: 0.1893 - val_regr_out_rmse: 0.9531 - val_regr_out_mape: 200.6976 - val_p_clsf_auc: 0.6987
# Epoch 6/500
# 557/557 [==============================] - 3s 6ms/step - loss: 1.1875 - regr_out_loss: 0.9710 - p_clsf_loss: 0.2164 - regr_out_rmse: 0.9854 - regr_out_mape: 233.8951 - p_clsf_auc: 0.6317 - val_loss: 1.0917 - val_regr_out_loss: 0.9037 - val_p_clsf_loss: 0.1880 - val_regr_out_rmse: 0.9506 - val_regr_out_mape: 223.2782 - val_p_clsf_auc: 0.7096
# Epoch 7/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1847 - regr_out_loss: 0.9710 - p_clsf_loss: 0.2138 - regr_out_rmse: 0.9854 - regr_out_mape: 244.0028 - p_clsf_auc: 0.6433 - val_loss: 1.0899 - val_regr_out_loss: 0.9029 - val_p_clsf_loss: 0.1870 - val_regr_out_rmse: 0.9502 - val_regr_out_mape: 221.6337 - val_p_clsf_auc: 0.7157
# Epoch 8/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1810 - regr_out_loss: 0.9676 - p_clsf_loss: 0.2134 - regr_out_rmse: 0.9837 - regr_out_mape: 239.4816 - p_clsf_auc: 0.6445 - val_loss: 1.0881 - val_regr_out_loss: 0.9028 - val_p_clsf_loss: 0.1853 - val_regr_out_rmse: 0.9502 - val_regr_out_mape: 227.0703 - val_p_clsf_auc: 0.7203
# Epoch 9/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1787 - regr_out_loss: 0.9673 - p_clsf_loss: 0.2114 - regr_out_rmse: 0.9835 - regr_out_mape: 248.2237 - p_clsf_auc: 0.6557 - val_loss: 1.0851 - val_regr_out_loss: 0.8997 - val_p_clsf_loss: 0.1854 - val_regr_out_rmse: 0.9485 - val_regr_out_mape: 225.3735 - val_p_clsf_auc: 0.7238
# Epoch 10/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1781 - regr_out_loss: 0.9678 - p_clsf_loss: 0.2103 - regr_out_rmse: 0.9838 - regr_out_mape: 257.1307 - p_clsf_auc: 0.6542 - val_loss: 1.0827 - val_regr_out_loss: 0.8979 - val_p_clsf_loss: 0.1848 - val_regr_out_rmse: 0.9476 - val_regr_out_mape: 229.8328 - val_p_clsf_auc: 0.7252
# Epoch 11/500
# 557/557 [==============================] - 3s 5ms/step - loss: 1.1714 - regr_out_loss: 0.9645 - p_clsf_loss: 0.2069 - regr_out_rmse: 0.9821 - regr_out_mape: 249.5899 - p_clsf_auc: 0.6718 - val_loss: 1.0805 - val_regr_out_loss: 0.8976 - val_p_clsf_loss: 0.1830 - val_regr_out_rmse: 0.9474 - val_regr_out_mape: 234.1607 - val_p_clsf_auc: 0.7289
# Epoch 12/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1714 - regr_out_loss: 0.9630 - p_clsf_loss: 0.2084 - regr_out_rmse: 0.9813 - regr_out_mape: 245.1679 - p_clsf_auc: 0.6610 - val_loss: 1.0802 - val_regr_out_loss: 0.8961 - val_p_clsf_loss: 0.1841 - val_regr_out_rmse: 0.9466 - val_regr_out_mape: 228.8088 - val_p_clsf_auc: 0.7284
# Epoch 13/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1697 - regr_out_loss: 0.9635 - p_clsf_loss: 0.2062 - regr_out_rmse: 0.9816 - regr_out_mape: 257.7532 - p_clsf_auc: 0.6722 - val_loss: 1.0789 - val_regr_out_loss: 0.8952 - val_p_clsf_loss: 0.1837 - val_regr_out_rmse: 0.9461 - val_regr_out_mape: 222.3633 - val_p_clsf_auc: 0.7309
# Epoch 14/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1661 - regr_out_loss: 0.9607 - p_clsf_loss: 0.2053 - regr_out_rmse: 0.9802 - regr_out_mape: 265.2875 - p_clsf_auc: 0.6760 - val_loss: 1.0769 - val_regr_out_loss: 0.8936 - val_p_clsf_loss: 0.1833 - val_regr_out_rmse: 0.9453 - val_regr_out_mape: 219.0117 - val_p_clsf_auc: 0.7319
# Epoch 15/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1660 - regr_out_loss: 0.9619 - p_clsf_loss: 0.2041 - regr_out_rmse: 0.9807 - regr_out_mape: 256.4653 - p_clsf_auc: 0.6808 - val_loss: 1.0770 - val_regr_out_loss: 0.8950 - val_p_clsf_loss: 0.1820 - val_regr_out_rmse: 0.9460 - val_regr_out_mape: 220.7197 - val_p_clsf_auc: 0.7328
# Epoch 16/500
# 557/557 [==============================] - 3s 5ms/step - loss: 1.1640 - regr_out_loss: 0.9599 - p_clsf_loss: 0.2041 - regr_out_rmse: 0.9798 - regr_out_mape: 259.7308 - p_clsf_auc: 0.6807 - val_loss: 1.0756 - val_regr_out_loss: 0.8935 - val_p_clsf_loss: 0.1821 - val_regr_out_rmse: 0.9453 - val_regr_out_mape: 225.0802 - val_p_clsf_auc: 0.7367
# Epoch 17/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1623 - regr_out_loss: 0.9600 - p_clsf_loss: 0.2023 - regr_out_rmse: 0.9798 - regr_out_mape: 269.0080 - p_clsf_auc: 0.6865 - val_loss: 1.0750 - val_regr_out_loss: 0.8932 - val_p_clsf_loss: 0.1818 - val_regr_out_rmse: 0.9451 - val_regr_out_mape: 224.4890 - val_p_clsf_auc: 0.7354
# Epoch 18/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1583 - regr_out_loss: 0.9572 - p_clsf_loss: 0.2012 - regr_out_rmse: 0.9783 - regr_out_mape: 270.2475 - p_clsf_auc: 0.6927 - val_loss: 1.0757 - val_regr_out_loss: 0.8922 - val_p_clsf_loss: 0.1835 - val_regr_out_rmse: 0.9446 - val_regr_out_mape: 218.6179 - val_p_clsf_auc: 0.7342
# Epoch 19/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1613 - regr_out_loss: 0.9596 - p_clsf_loss: 0.2017 - regr_out_rmse: 0.9796 - regr_out_mape: 247.9153 - p_clsf_auc: 0.6882 - val_loss: 1.0717 - val_regr_out_loss: 0.8896 - val_p_clsf_loss: 0.1822 - val_regr_out_rmse: 0.9432 - val_regr_out_mape: 228.6493 - val_p_clsf_auc: 0.7353
# Epoch 20/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1595 - regr_out_loss: 0.9561 - p_clsf_loss: 0.2034 - regr_out_rmse: 0.9778 - regr_out_mape: 266.5166 - p_clsf_auc: 0.6797 - val_loss: 1.0729 - val_regr_out_loss: 0.8907 - val_p_clsf_loss: 0.1822 - val_regr_out_rmse: 0.9438 - val_regr_out_mape: 224.4334 - val_p_clsf_auc: 0.7357
# Epoch 21/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1566 - regr_out_loss: 0.9548 - p_clsf_loss: 0.2018 - regr_out_rmse: 0.9771 - regr_out_mape: 272.5794 - p_clsf_auc: 0.6885 - val_loss: 1.0710 - val_regr_out_loss: 0.8891 - val_p_clsf_loss: 0.1819 - val_regr_out_rmse: 0.9429 - val_regr_out_mape: 231.0080 - val_p_clsf_auc: 0.7348
# Epoch 22/500
# 557/557 [==============================] - 3s 6ms/step - loss: 1.1539 - regr_out_loss: 0.9531 - p_clsf_loss: 0.2008 - regr_out_rmse: 0.9763 - regr_out_mape: 256.9438 - p_clsf_auc: 0.6920 - val_loss: 1.0695 - val_regr_out_loss: 0.8879 - val_p_clsf_loss: 0.1816 - val_regr_out_rmse: 0.9423 - val_regr_out_mape: 238.7227 - val_p_clsf_auc: 0.7344
# Epoch 23/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1510 - regr_out_loss: 0.9514 - p_clsf_loss: 0.1995 - regr_out_rmse: 0.9754 - regr_out_mape: 286.1537 - p_clsf_auc: 0.6983 - val_loss: 1.0711 - val_regr_out_loss: 0.8894 - val_p_clsf_loss: 0.1818 - val_regr_out_rmse: 0.9431 - val_regr_out_mape: 227.2793 - val_p_clsf_auc: 0.7366
# Epoch 24/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1525 - regr_out_loss: 0.9517 - p_clsf_loss: 0.2008 - regr_out_rmse: 0.9756 - regr_out_mape: 276.0310 - p_clsf_auc: 0.6930 - val_loss: 1.0732 - val_regr_out_loss: 0.8904 - val_p_clsf_loss: 0.1828 - val_regr_out_rmse: 0.9436 - val_regr_out_mape: 225.1015 - val_p_clsf_auc: 0.7359
# Epoch 25/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1533 - regr_out_loss: 0.9533 - p_clsf_loss: 0.2000 - regr_out_rmse: 0.9764 - regr_out_mape: 284.0649 - p_clsf_auc: 0.6966 - val_loss: 1.0714 - val_regr_out_loss: 0.8897 - val_p_clsf_loss: 0.1817 - val_regr_out_rmse: 0.9432 - val_regr_out_mape: 223.8617 - val_p_clsf_auc: 0.7370
# Epoch 26/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1520 - regr_out_loss: 0.9513 - p_clsf_loss: 0.2007 - regr_out_rmse: 0.9753 - regr_out_mape: 279.2271 - p_clsf_auc: 0.6921 - val_loss: 1.0721 - val_regr_out_loss: 0.8901 - val_p_clsf_loss: 0.1820 - val_regr_out_rmse: 0.9434 - val_regr_out_mape: 224.4160 - val_p_clsf_auc: 0.7352
# Epoch 27/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1469 - regr_out_loss: 0.9475 - p_clsf_loss: 0.1994 - regr_out_rmse: 0.9734 - regr_out_mape: 290.8718 - p_clsf_auc: 0.7003 - val_loss: 1.0687 - val_regr_out_loss: 0.8874 - val_p_clsf_loss: 0.1813 - val_regr_out_rmse: 0.9420 - val_regr_out_mape: 240.8074 - val_p_clsf_auc: 0.7373
# Epoch 28/500
# 557/557 [==============================] - 3s 5ms/step - loss: 1.1486 - regr_out_loss: 0.9486 - p_clsf_loss: 0.2000 - regr_out_rmse: 0.9740 - regr_out_mape: 289.7263 - p_clsf_auc: 0.6972 - val_loss: 1.0715 - val_regr_out_loss: 0.8899 - val_p_clsf_loss: 0.1817 - val_regr_out_rmse: 0.9433 - val_regr_out_mape: 225.1126 - val_p_clsf_auc: 0.7351
# Epoch 29/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1498 - regr_out_loss: 0.9507 - p_clsf_loss: 0.1991 - regr_out_rmse: 0.9751 - regr_out_mape: 275.9492 - p_clsf_auc: 0.7020 - val_loss: 1.0683 - val_regr_out_loss: 0.8866 - val_p_clsf_loss: 0.1817 - val_regr_out_rmse: 0.9416 - val_regr_out_mape: 232.6604 - val_p_clsf_auc: 0.7374
# Epoch 30/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1472 - regr_out_loss: 0.9487 - p_clsf_loss: 0.1985 - regr_out_rmse: 0.9740 - regr_out_mape: 275.5938 - p_clsf_auc: 0.7044 - val_loss: 1.0681 - val_regr_out_loss: 0.8868 - val_p_clsf_loss: 0.1813 - val_regr_out_rmse: 0.9417 - val_regr_out_mape: 234.7859 - val_p_clsf_auc: 0.7337
# Epoch 31/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1464 - regr_out_loss: 0.9476 - p_clsf_loss: 0.1989 - regr_out_rmse: 0.9734 - regr_out_mape: 281.8304 - p_clsf_auc: 0.7029 - val_loss: 1.0725 - val_regr_out_loss: 0.8898 - val_p_clsf_loss: 0.1827 - val_regr_out_rmse: 0.9433 - val_regr_out_mape: 225.0226 - val_p_clsf_auc: 0.7356
# Epoch 32/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1461 - regr_out_loss: 0.9479 - p_clsf_loss: 0.1982 - regr_out_rmse: 0.9736 - regr_out_mape: 277.4444 - p_clsf_auc: 0.7062 - val_loss: 1.0695 - val_regr_out_loss: 0.8878 - val_p_clsf_loss: 0.1817 - val_regr_out_rmse: 0.9422 - val_regr_out_mape: 235.2481 - val_p_clsf_auc: 0.7333
# Epoch 33/500
# 557/557 [==============================] - 3s 6ms/step - loss: 1.1470 - regr_out_loss: 0.9486 - p_clsf_loss: 0.1984 - regr_out_rmse: 0.9739 - regr_out_mape: 290.7700 - p_clsf_auc: 0.7051 - val_loss: 1.0718 - val_regr_out_loss: 0.8898 - val_p_clsf_loss: 0.1820 - val_regr_out_rmse: 0.9433 - val_regr_out_mape: 225.1547 - val_p_clsf_auc: 0.7353
# Epoch 34/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1443 - regr_out_loss: 0.9464 - p_clsf_loss: 0.1979 - regr_out_rmse: 0.9728 - regr_out_mape: 277.5686 - p_clsf_auc: 0.7059 - val_loss: 1.0679 - val_regr_out_loss: 0.8863 - val_p_clsf_loss: 0.1816 - val_regr_out_rmse: 0.9414 - val_regr_out_mape: 247.0578 - val_p_clsf_auc: 0.7378
# Epoch 35/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1392 - regr_out_loss: 0.9427 - p_clsf_loss: 0.1965 - regr_out_rmse: 0.9709 - regr_out_mape: 292.4534 - p_clsf_auc: 0.7124 - val_loss: 1.0697 - val_regr_out_loss: 0.8874 - val_p_clsf_loss: 0.1823 - val_regr_out_rmse: 0.9420 - val_regr_out_mape: 240.8797 - val_p_clsf_auc: 0.7344
# Epoch 36/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1436 - regr_out_loss: 0.9465 - p_clsf_loss: 0.1971 - regr_out_rmse: 0.9729 - regr_out_mape: 275.3323 - p_clsf_auc: 0.7113 - val_loss: 1.0685 - val_regr_out_loss: 0.8868 - val_p_clsf_loss: 0.1817 - val_regr_out_rmse: 0.9417 - val_regr_out_mape: 238.1054 - val_p_clsf_auc: 0.7345
# Epoch 37/500
# 557/557 [==============================] - 2s 4ms/step - loss: 1.1383 - regr_out_loss: 0.9415 - p_clsf_loss: 0.1968 - regr_out_rmse: 0.9703 - regr_out_mape: 284.4692 - p_clsf_auc: 0.7106 - val_loss: 1.0684 - val_regr_out_loss: 0.8874 - val_p_clsf_loss: 0.1810 - val_regr_out_rmse: 0.9420 - val_regr_out_mape: 235.1495 - val_p_clsf_auc: 0.7357
# Epoch 38/500
# 557/557 [==============================] - 3s 5ms/step - loss: 1.1389 - regr_out_loss: 0.9421 - p_clsf_loss: 0.1968 - regr_out_rmse: 0.9706 - regr_out_mape: 284.0825 - p_clsf_auc: 0.7107 - val_loss: 1.0693 - val_regr_out_loss: 0.8871 - val_p_clsf_loss: 0.1822 - val_regr_out_rmse: 0.9419 - val_regr_out_mape: 235.2769 - val_p_clsf_auc: 0.7349
# Epoch 39/500
# 557/557 [==============================] - 3s 5ms/step - loss: 1.1429 - regr_out_loss: 0.9451 - p_clsf_loss: 0.1978 - regr_out_rmse: 0.9722 - regr_out_mape: 287.4442 - p_clsf_auc: 0.7062 - val_loss: 1.0697 - val_regr_out_loss: 0.8877 - val_p_clsf_loss: 0.1820 - val_regr_out_rmse: 0.9422 - val_regr_out_mape: 234.8307 - val_p_clsf_auc: 0.7350

# %%
fig = plot_metrics(history, metrics=['regr_out_loss', 'p_clsf_loss', 'regr_out_rmse', 'p_clsf_auc'])

plt.show()

# %%
model.save('models/mtl_model')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
model.predict(X_test.loc[0:1,:])
# Out:
# 1/1 [==============================] - 0s 233ms/step
# [array([[0.32743996],
#         [0.47319877]], dtype=float32), array([[0.14814033],
#         [0.20063563]], dtype=float32)]

# %% [markdown]
# # SHAP Explanations

# %%
# !pip install shap

# %%
import shap
from shap import DeepExplainer

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Regression Model

# %%
regr_model = Model(model.input, model.output[0])

# %%
sample_data = X_train.sample(n=2000, random_state=2) # background dataset

explain_dataset = X_train.sample(n=5000, random_state=3) # data on which we want explanations

# %%
deep_explainer = DeepExplainer(regr_model, 
                               [sample_data.values])
# Out:
# keras is no longer supported, please use tf.keras instead.
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.

# %%
shap.explainers._deep.deep_tf.op_handlers["AddV2"] = shap.explainers._deep.deep_tf.passthrough #this solves the "shap_ADDV2" problem but another one will appear
# shap.explainers._deep.deep_tf.op_handlers["FusedBatchNormV3"] = shap.explainers._deep.deep_tf.passthrough #this solves the next problem which allows you to run the DeepExplainer.

# %%
shap_vals = deep_explainer.shap_values(explain_dataset.values)
# Out:
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ## Summary Plots

# %%
shap.summary_plot(shap_values=shap_vals[0],
                  features=explain_dataset,
                  feature_names=X_train.columns,
                  max_display=20,
                  plot_type='bar')

# %%
shap.summary_plot(shap_values=shap_vals[0],
                  features=explain_dataset,
                  feature_names=X_train.columns,
                  max_display=20)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# ## Sample Explanations

# %%
def sample_level_details(explain_index, explain_dataset, bg_data, shap_vals):
    sample_detail = pd.concat([explain_dataset.iloc[explain_index,:], bg_data.mean()], axis=1)

    sample_detail.columns = ['sample_value', 'mean_bg_value']
    sample_detail['contribution'] = shap_vals[0][explain_index]

    sample_detail = sample_detail.sort_values('contribution', ascending=False)

    return sample_detail

# %%
index=20
shap.force_plot(base_value=deep_explainer.expected_value[0].numpy(),
                shap_values=shap_vals[0][index],
                features=explain_dataset.iloc[index,:],
                feature_names=X_train.columns)
# Out:
# <div id='iVS7NY3ZGYLK5MELLUN4W'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.008235509507358074, "outValue": 0.013030287505654358, "link": "identity", "featureNames": ["timedelta", "n_tokens_title", "n_tokens_content", "n_unique_tokens", "n_non_stop_words", "n_non_stop_unique_tokens", "num_hrefs", "num_self_hrefs", "num_imgs", "num_videos", "average_token_length", "num_keywords", "data_channel_is_lifestyle", "data_channel_is_entertainment", "data_channel_is_bus", "data_channel_is_socmed", "data_channel_is_tech", "data_channel_is_world", "kw_min_min", "kw_max_min", "kw_avg_min", "kw_min_max", "kw_max_max", "kw_avg_max", "kw_min_avg", "kw_max_avg", "kw_avg_avg", "self_reference_min_shares", "self_reference_max_shares", "self_reference_avg_sharess", "weekday_is_monday", "weekday_is_tuesday", "weekday_is_wednesday", "weekday_is_thursday", "weekday_is_friday", "weekday_is_saturday", "weekday_is_sunday", "is_weekend", "LDA_00", "LDA_01", "LDA_02", "LDA_03", "LDA_04", "global_subjectivity", "global_sentiment_polarity", "global_rate_positive_words", "global_rate_negative_words", "rate_positive_words", "rate_negative_words", "avg_positive_polarity", "min_positive_polarity", "max_positive_polarity", "avg_negative_polarity", "min_negative_polarity", "max_negative_polarity", "title_subjectivity", "title_sentiment_polarity", "abs_title_subjectivity", "abs_title_sentiment_polarity"], "features": {"0": {"effect": -0.0021956963091039764, "value": -0.34655385434031516}, "1": {"effect": 0.020267557195733317, "value": 1.2304164012755354}, "2": {"effect": -0.0033224884641642263, "value": -0.8398483460151427}, "3": {"effect": 0.0007951944327160223, "value": 0.03136814077085548}, "4": {"effect": -0.00023228168333993803, "value": 9.664872183022615e-05}, "5": {"effect": -0.00032789127730824307, "value": 0.021018305860538437}, "6": {"effect": -0.008369042541079756, "value": -0.25182838506418964}, "7": {"effect": -0.009105434783334906, "value": 0.4442540155108558}, "8": {"effect": -0.005434809889672431, "value": -0.3063865537333241}, "9": {"effect": -0.00011413123058377036, "value": -0.3023835362058636}, "10": {"effect": -5.402902707427484e-05, "value": 0.16626989313133822}, "11": {"effect": -0.0010580653836893786, "value": -0.6384057509112063}, "12": {"effect": 0.0025908076607156546, "value": 0.0}, "13": {"effect": 0.01527979302732274, "value": 0.0}, "14": {"effect": 0.012499542276345891, "value": 0.0}, "15": {"effect": 0.007203522992433136, "value": 1.0}, "16": {"effect": -0.00200518620881121, "value": 0.0}, "17": {"effect": 0.0021275761957198257, "value": 0.0}, "18": {"effect": -0.002967125803615062, "value": -0.38870293935607103}, "19": {"effect": 0.00032823743233736734, "value": -0.14224234635092078}, "20": {"effect": -0.0009124864689214334, "value": -0.21141055404453862}, "21": {"effect": 0.0006475567961133785, "value": -0.013923009391900266}, "22": {"effect": -0.0013789332392927917, "value": 0.4235990396480566}, "23": {"effect": -0.0009395341926734331, "value": -0.1043887925884788}, "24": {"effect": 0.002329514120485526, "value": 1.395116974746738}, "25": {"effect": -0.002934087659661878, "value": -0.2845997959171878}, "26": {"effect": 0.0011599473319736733, "value": 0.10404531995955839}, "27": {"effect": -0.0011549586627472427, "value": -0.06692581744680569}, "28": {"effect": -0.001981047072646001, "value": -0.18766684442854828}, "29": {"effect": -0.00703367198809338, "value": -0.15428483885589506}, "30": {"effect": -0.000978160025408215, "value": 0.0}, "31": {"effect": 0.001621736410783342, "value": 0.0}, "32": {"effect": 0.0057699583681824155, "value": 0.0}, "33": {"effect": -0.0049657099263704365, "value": 1.0}, "34": {"effect": 0.0011871872355859524, "value": 0.0}, "35": {"effect": 0.00037982080457004487, "value": 0.0}, "36": {"effect": -0.0019658824110083514, "value": 0.0}, "37": {"effect": -0.0045459250229760075, "value": 0.0}, "38": {"effect": 0.004079475388564812, "value": 0.43353035995265776}, "39": {"effect": -0.00 ...
#     document.getElementById('iVS7NY3ZGYLK5MELLUN4W')
#   );
# </script>

# %%
sample_detail = sample_level_details(explain_index=20,
                                    explain_dataset=explain_dataset,
                                    bg_data=sample_data,
                                    shap_vals=shap_vals)
sample_detail
# Out:
#                                sample_value  mean_bg_value  contribution
# n_tokens_title                     1.230416      -0.007118      0.020268
# LDA_02                            -0.649146      -0.023616      0.019786
# rate_negative_words               -1.843560      -0.045994      0.019053
# data_channel_is_entertainment      0.000000       0.180500      0.015280
# data_channel_is_bus                0.000000       0.155000      0.012500
# global_rate_positive_words         2.674961       0.038616      0.012488
# data_channel_is_socmed             1.000000       0.062000      0.007204
# weekday_is_wednesday               0.000000       0.190500      0.005770
# max_positive_polarity             -0.228358       0.036095      0.005709
# min_positive_polarity             -0.869619      -0.001005      0.005685
# abs_title_sentiment_polarity       0.492178       0.045896      0.005433
# LDA_00                             0.433530       0.025502      0.004079
# title_sentiment_polarity           0.735815       0.025682      0.003360
# data_channel_is_lifestyle          0.000000       0.060500      0.002591
# kw_min_avg                         1.395117      -0.014032      0.002330
# data_channel_is_world              0.000000       0.209000      0.002128
# max_negative_polarity              1.129827       0.054778      0.001660
# weekday_is_tuesday                 0.000000       0.196000      0.001622
# weekday_is_friday                  0.000000       0.142000      0.001187
# kw_avg_avg                         0.104045      -0.005399      0.001160
# n_unique_tokens                    0.031368      -0.006114      0.000795
# kw_min_max                        -0.013923       0.057944      0.000648
# title_subjectivity                 0.005954       0.073463      0.000459
# weekday_is_saturday                0.000000       0.061000      0.000380
# kw_max_min                        -0.142242      -0.018164      0.000328
# global_sentiment_polarity          1.536462       0.066391      0.000249
# average_token_length               0.166270       0.010944     -0.000054
# num_videos                        -0.302384       0.011359     -0.000114
# n_non_stop_words                   0.000097      -0.004887     -0.000232
# n_non_stop_unique_tokens           0.021018      -0.006212     -0.000328
# kw_avg_min                        -0.211411      -0.012764     -0.000912
# kw_avg_max                        -0.104389      -0.013838     -0.000940
# weekday_is_monday                  0.000000       0.156000     -0.000978
# num_keywords                      -0.638406      -0.006731     -0.001058
# self_reference_min_shares         -0.066926       0.014182     -0.001155
# kw_max_max                         0.423599      -0.015327     -0.001379
# LDA_01                            -0.491278      -0.016157     -0.001933
# weekday_is_sunday                  0.000000       0.074000     -0.001966
# self_reference_max_shares         -0.187667       0.043909     -0.001981
# data_channel_is_tech               0.000000       0.185500     -0.002005
# timedelta                         -0.346554       0.036143     -0.002196
# min_negative_polarity              1.796307       0.007259     -0.002364
# abs_title_subjectivity            -0.660875      -0.037428     -0.002477
# avg_positive_polarity             -0.433649       0.015747     -0.002835
# kw_max_avg                        -0.284600      -0.006350     -0.002934
# kw_min_min                        -0.388703       0.012269     -0.002967
# n_tokens_content                  -0.839848       0.028765     -0.003322
# LDA_04                             1.267003       0.019012     -0.003634
# global_rate_negative_words        -1.542395      -0.009748     -0.003639
# is_weekend                         0.000000       0.135000     -0.004546
# weekday_is_thursday                1.000000       0.180500     -0.004966
# num_imgs                          -0.306387       0.029797     -0.005435
# self_reference_avg_sharess        -0.154285       0.025265     -0.007034
# num_hrefs                         -0.251828       0.048235     -0.008369
# num_self_hrefs                     0.444254       0.036903     -0.009105
# LDA_03                            -0.642831      -0.006712     -0.010260
# global_subjectivity               -0.397650       0.022878     -0.012421
# avg_negative_polarity              2.031672       0.029813     -0.015983
# rate_positive_words                1.670557       0.050340     -0.027832

# %% [markdown]
# ## Classification Model

# %%
clsf_model = Model(model.input, model.output[1])

# %%
deep_explainer_clsf = DeepExplainer(clsf_model, 
                                    [sample_data.values])
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.

# %%
shap.explainers._deep.deep_tf.op_handlers["AddV2"] = shap.explainers._deep.deep_tf.passthrough #this solves the "shap_ADDV2" problem but another one will appear
# shap.explainers._deep.deep_tf.op_handlers["FusedBatchNormV3"] = shap.explainers._deep.deep_tf.passthrough #this solves the next problem which allows you to run the DeepExplainer.

# %%
shap_vals_clsf = deep_explainer_clsf.shap_values(explain_dataset.values)
# Out:
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Summary Plots

# %%
shap.summary_plot(shap_values=shap_vals_clsf[0],
                  features=explain_dataset,
                  feature_names=X_train.columns,
                  max_display=20,
                  plot_type='bar')

# %%
shap.summary_plot(shap_values=shap_vals_clsf[0],
                  features=explain_dataset,
                  feature_names=X_train.columns,
                  max_display=20)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %% [markdown]
# ## Sample Explanations

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
index=20
shap.force_plot(base_value=deep_explainer_clsf.expected_value[0].numpy(),
                shap_values=shap_vals_clsf[0][index],
                features=explain_dataset.iloc[index,:],
                feature_names=X_train.columns)
# Out:
# <div id='iHVB5RTVE44ZEFIRJNDLQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.061560798436403275, "outValue": 0.07414424978835575, "link": "identity", "featureNames": ["timedelta", "n_tokens_title", "n_tokens_content", "n_unique_tokens", "n_non_stop_words", "n_non_stop_unique_tokens", "num_hrefs", "num_self_hrefs", "num_imgs", "num_videos", "average_token_length", "num_keywords", "data_channel_is_lifestyle", "data_channel_is_entertainment", "data_channel_is_bus", "data_channel_is_socmed", "data_channel_is_tech", "data_channel_is_world", "kw_min_min", "kw_max_min", "kw_avg_min", "kw_min_max", "kw_max_max", "kw_avg_max", "kw_min_avg", "kw_max_avg", "kw_avg_avg", "self_reference_min_shares", "self_reference_max_shares", "self_reference_avg_sharess", "weekday_is_monday", "weekday_is_tuesday", "weekday_is_wednesday", "weekday_is_thursday", "weekday_is_friday", "weekday_is_saturday", "weekday_is_sunday", "is_weekend", "LDA_00", "LDA_01", "LDA_02", "LDA_03", "LDA_04", "global_subjectivity", "global_sentiment_polarity", "global_rate_positive_words", "global_rate_negative_words", "rate_positive_words", "rate_negative_words", "avg_positive_polarity", "min_positive_polarity", "max_positive_polarity", "avg_negative_polarity", "min_negative_polarity", "max_negative_polarity", "title_subjectivity", "title_sentiment_polarity", "abs_title_subjectivity", "abs_title_sentiment_polarity"], "features": {"0": {"effect": -0.0012986885774718816, "value": -0.34655385434031516}, "1": {"effect": 0.008541426503902542, "value": 1.2304164012755354}, "2": {"effect": 0.0010072910130618678, "value": -0.8398483460151427}, "3": {"effect": 0.00036737945425668905, "value": 0.03136814077085548}, "4": {"effect": -0.00013955157029575194, "value": 9.664872183022615e-05}, "5": {"effect": -4.07894352819148e-05, "value": 0.021018305860538437}, "6": {"effect": -0.002419153286178373, "value": -0.25182838506418964}, "7": {"effect": -0.002626933680412172, "value": 0.4442540155108558}, "8": {"effect": -0.001977442147133339, "value": -0.3063865537333241}, "9": {"effect": -0.00115360220997058, "value": -0.3023835362058636}, "10": {"effect": 0.00010440487501825556, "value": 0.16626989313133822}, "11": {"effect": 0.0011953820028196848, "value": -0.6384057509112063}, "12": {"effect": 0.0006351699987681059, "value": 0.0}, "13": {"effect": 0.005382408217526972, "value": 0.0}, "14": {"effect": 0.005418260598089546, "value": 0.0}, "15": {"effect": 0.0025685002816324244, "value": 1.0}, "16": {"effect": 0.0010238134228693525, "value": 0.0}, "17": {"effect": 0.001142241980757234, "value": 0.0}, "18": {"effect": -0.0022261607558703585, "value": -0.38870293935607103}, "19": {"effect": 0.00010063415171813035, "value": -0.14224234635092078}, "20": {"effect": -0.0001616285441885544, "value": -0.21141055404453862}, "21": {"effect": 0.0001673249644588515, "value": -0.013923009391900266}, "22": {"effect": 0.0005560585303832871, "value": 0.4235990396480566}, "23": {"effect": 0.00019008748495516378, "value": -0.1043887925884788}, "24": {"effect": 0.0023109508524190676, "value": 1.395116974746738}, "25": {"effect": -0.0015374708993506395, "value": -0.2845997959171878}, "26": {"effect": 0.0024282283151673277, "value": 0.10404531995955839}, "27": {"effect": -0.00015019259087517399, "value": -0.06692581744680569}, "28": {"effect": -0.0007967465512360626, "value": -0.18766684442854828}, "29": {"effect": -0.0018491153971252037, "value": -0.15428483885589506}, "30": {"effect": -5.356776891494519e-05, "value": 0.0}, "31": {"effect": 0.0013394111991910905, "value": 0.0}, "32": {"effect": 0.002368963517496013, "value": 0.0}, "33": {"effect": -0.0027361805138327784, "value": 1.0}, "34": {"effect": 6.643496149627026e-05, "value": 0.0}, "35": {"effect": 0.00017463913558458445, "value": 0.0}, "36": {"effect": 0.0003043961462608422, "value": 0.0}, "37": {"effect": -0.001073744078312302, "value": 0.0}, "38": {"effect": 0.0010138273538825174, "value": 0.43353035995265776}, "39": {"effect": -0.0 ...
#     document.getElementById('iHVB5RTVE44ZEFIRJNDLQ')
#   );
# </script>

# %%
sample_detail = sample_level_details(explain_index=20,
                                    explain_dataset=explain_dataset,
                                    bg_data=sample_data,
                                    shap_vals=shap_vals_clsf)
sample_detail
# Out:
#                                sample_value  mean_bg_value  contribution
# n_tokens_title                     1.230416      -0.007118      0.008541
# LDA_02                            -0.649146      -0.023616      0.005835
# data_channel_is_bus                0.000000       0.155000      0.005418
# data_channel_is_entertainment      0.000000       0.180500      0.005382
# global_rate_positive_words         2.674961       0.038616      0.003871
# rate_negative_words               -1.843560      -0.045994      0.003153
# abs_title_sentiment_polarity       0.492178       0.045896      0.002856
# data_channel_is_socmed             1.000000       0.062000      0.002569
# max_negative_polarity              1.129827       0.054778      0.002531
# kw_avg_avg                         0.104045      -0.005399      0.002428
# weekday_is_wednesday               0.000000       0.190500      0.002369
# kw_min_avg                         1.395117      -0.014032      0.002311
# max_positive_polarity             -0.228358       0.036095      0.002136
# min_positive_polarity             -0.869619      -0.001005      0.001891
# global_sentiment_polarity          1.536462       0.066391      0.001401
# weekday_is_tuesday                 0.000000       0.196000      0.001339
# num_keywords                      -0.638406      -0.006731      0.001195
# data_channel_is_world              0.000000       0.209000      0.001142
# data_channel_is_tech               0.000000       0.185500      0.001024
# LDA_00                             0.433530       0.025502      0.001014
# n_tokens_content                  -0.839848       0.028765      0.001007
# data_channel_is_lifestyle          0.000000       0.060500      0.000635
# title_subjectivity                 0.005954       0.073463      0.000633
# title_sentiment_polarity           0.735815       0.025682      0.000557
# kw_max_max                         0.423599      -0.015327      0.000556
# n_unique_tokens                    0.031368      -0.006114      0.000367
# weekday_is_sunday                  0.000000       0.074000      0.000304
# global_rate_negative_words        -1.542395      -0.009748      0.000264
# kw_avg_max                        -0.104389      -0.013838      0.000190
# weekday_is_saturday                0.000000       0.061000      0.000175
# kw_min_max                        -0.013923       0.057944      0.000167
# average_token_length               0.166270       0.010944      0.000104
# kw_max_min                        -0.142242      -0.018164      0.000101
# weekday_is_friday                  0.000000       0.142000      0.000066
# n_non_stop_unique_tokens           0.021018      -0.006212     -0.000041
# weekday_is_monday                  0.000000       0.156000     -0.000054
# LDA_01                            -0.491278      -0.016157     -0.000133
# n_non_stop_words                   0.000097      -0.004887     -0.000140
# self_reference_min_shares         -0.066926       0.014182     -0.000150
# kw_avg_min                        -0.211411      -0.012764     -0.000162
# abs_title_subjectivity            -0.660875      -0.037428     -0.000169
# avg_positive_polarity             -0.433649       0.015747     -0.000495
# self_reference_max_shares         -0.187667       0.043909     -0.000797
# is_weekend                         0.000000       0.135000     -0.001074
# num_videos                        -0.302384       0.011359     -0.001154
# timedelta                         -0.346554       0.036143     -0.001299
# kw_max_avg                        -0.284600      -0.006350     -0.001537
# min_negative_polarity              1.796307       0.007259     -0.001648
# self_reference_avg_sharess        -0.154285       0.025265     -0.001849
# num_imgs                          -0.306387       0.029797     -0.001977
# kw_min_min                        -0.388703       0.012269     -0.002226
# num_hrefs                         -0.251828       0.048235     -0.002419
# num_self_hrefs                     0.444254       0.036903     -0.002627
# weekday_is_thursday                1.000000       0.180500     -0.002736
# global_subjectivity               -0.397650       0.022878     -0.003251
# LDA_04                             1.267003       0.019012     -0.003483
# LDA_03                            -0.642831      -0.006712     -0.003962
# avg_negative_polarity              2.031672       0.029813     -0.006651
# rate_positive_words                1.670557       0.050340     -0.010918
